# %%
import numpy as np
import cv2 
from glob import glob
import matplotlib.pyplot as plt

# %%
#import path image
fpath = glob('./data/female/*.jpg')
mpath = glob('./data/male/*.jpg')
print (fpath)
# Out:
# ['./data/female\\female_000000.jpg', './data/female\\female_000001.jpg', './data/female\\female_000002.jpg', './data/female\\female_000003.jpg', './data/female\\female_000004.jpg', './data/female\\female_000005.jpg', './data/female\\female_000006.jpg', './data/female\\female_000007.jpg', './data/female\\female_000008.jpg', './data/female\\female_000009.jpg', './data/female\\female_000010.jpg', './data/female\\female_000011.jpg', './data/female\\female_000012.jpg', './data/female\\female_000013.jpg', './data/female\\female_000014.jpg', './data/female\\female_000018.jpg', './data/female\\female_000019.jpg', './data/female\\female_000020.jpg', './data/female\\female_000021.jpg', './data/female\\female_000024.jpg', './data/female\\female_000025.jpg', './data/female\\female_000026.jpg', './data/female\\female_000028.jpg', './data/female\\female_000030.jpg', './data/female\\female_000031.jpg', './data/female\\female_000032.jpg', './data/female\\female_000034.jpg', './data/female\\female_00
# ...

# %%
print ('numero de imagenes en la carpeta female = ',len(fpath))
print ('numero de imagenes en la carpeta male = ',len(mpath))
# Out:
# numero de imagenes en la carpeta female =  4762
# numero de imagenes en la carpeta male =  5399
